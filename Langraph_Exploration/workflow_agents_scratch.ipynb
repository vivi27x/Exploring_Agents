# %%
# ollama run llama3.1:8b-instruct-q4_K_M

# %%
import os
from langchain.chat_models import init_chat_model

os.environ["GOOGLE_API_KEY"] = ""

model = init_chat_model("google_genai:gemini-2.5-flash-lite")

# %%
# pip install langchain-ollama langchain-core
from langchain_ollama import ChatOllama
llm = ChatOllama(model="llama3.1:8b-instruct-q4_K_M", temperature=0.2)

# then wrap this llm in your LangGraph nodes as usual

# %%
response = llm.invoke("Why do parrots talk?")
# Out:
# ---------------------------------------------------------------------------
# ResponseError                             Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 response = llm.invoke("Why do parrots talk?")
#
# File ~/GITHUB/Exploring_Agents/.venv/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:379, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     365 @override
#     366 def invoke(
#     367     self,
#    (...)    372     **kwargs: Any,
#     373 ) -> AIMessage:
#     374     config = ensure_config(config)
#     375     return cast(
#     376         "AIMessage",
#     377         cast(
#     378             "ChatGeneration",
# --> 379             self.generate_prompt(
#     380                 [self._convert_input(input)],
#     381                 stop=stop,
#     382                 callbacks=config.get("callbacks"),
#     383                 tags=config.get("tags"),
#     384                 metadata=config.get("metadata"),
#     385                 run_name=config.get("run_name"),
#     386                 run_id=config.pop("run_id", None),
#     387                 **kwargs,
#     388             ).generations[0][0],
#     389         ).message,
#     390     )
#
# File ~/GITHUB/Exploring_Agents/.venv/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:1088, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1079 @override
#    1080 def generate_prompt(
#    1081     self,
#    (...)   1085     **kwargs: Any,
#    1086 ) -> LLMResult:
#    1087     prompt_messages = [p.to_messages() for p in prompts]
# -> 1088     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/GITHUB/Exploring_Agents/.venv/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:903, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     900 for i, m in enumerate(input_messages):
#     901     try:
#     902         results.append(
# --> 903             self._generate_with_cache(
#     904                 m,
#     905                 stop=stop,
#     906                 run_manager=run_managers[i] if run_managers else None,
#     907                 **kwargs,
#     908             )
#     909         )
#     910     except BaseException as e:
#     911         if run_managers:
#
# File ~/GITHUB/Exploring_Agents/.venv/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:1192, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1190     result = generate_from_stream(iter(chunks))
#    1191 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1192     result = self._generate(
#    1193         messages, stop=stop, run_manager=run_manager, **kwargs
#    1194     )
#    1195 else:
#    1196     result = self._generate(messages, stop=stop, **kwargs)
#
# File ~/GITHUB/Exploring_Agents/.venv/lib/python3.12/site-packages/langchain_ollama/chat_models.py:1025, in ChatOllama._generate(self, messages, stop, run_manager, **kwargs)
#    1018 def _generate(
#    1019     self,
#    1020     messages: list[BaseMessage],
#    (...)   1023     **kwargs: Any,
#    1024 ) -> ChatResult:
# -> 1025     final_chunk = self._chat_stream_with_aggregation(
#    1026         messages, stop, run_manager, verbose=self.verbose, **kwargs
#    1027     )
#    1028     generation_info = final_chunk.generation_info
#    1029     chat_generation = ChatGeneration(
#    1030         message=AIMessage(
#    1031             content=final_chunk.text,
#    (...)   1038         generation_info=generation_info,
#    1039     )
#
# File ~/GITHUB/Exploring_Agents/.venv/lib/python3.12/site-packages/langchain_ollama/chat_models.py:960, in ChatOllama._chat_stream_with_aggregation(self, messages, stop, run_manager, verbose, **kwargs)
#     951 def _chat_stream_with_aggregation(
#     952     self,
#     953     messages: list[BaseMessage],
#    (...)    957     **kwargs: Any,
#     958 ) -> ChatGenerationChunk:
#     959     final_chunk = None
# --> 960     for chunk in self._iterate_over_stream(messages, stop, **kwargs):
#     961         if final_chunk is None:
#     962             final_chunk = chunk
#
# File ~/GITHUB/Exploring_Agents/.venv/lib/python3.12/site-packages/langchain_ollama/chat_models.py:1049, in ChatOllama._iterate_over_stream(self, messages, stop, **kwargs)
#    1042 def _iterate_over_stream(
#    1043     self,
#    1044     messages: list[BaseMessage],
#    1045     stop: list[str] | None = None,
#    1046     **kwargs: Any,
#    1047 ) -> Iterator[ChatGenerationChunk]:
#    1048     reasoning = kwargs.get("reasoning", self.reasoning)
# -> 1049     for stream_resp in self._create_chat_stream(messages, stop, **kwargs):
#    1050         if not isinstance(stream_resp, str):
#    1051             content = (
#    1052                 stream_resp["message"]["content"]
#    1053                 if "message" in stream_resp and "content" in stream_resp["message"]
#    1054                 else ""
#    1055             )
#
# File ~/GITHUB/Exploring_Agents/.venv/lib/python3.12/site-packages/langchain_ollama/chat_models.py:947, in ChatOllama._create_chat_stream(self, messages, stop, **kwargs)
#     945 if chat_params["stream"]:
#     946     if self._client:
# --> 947         yield from self._client.chat(**chat_params)
#     948 elif self._client:
#     949     yield self._client.chat(**chat_params)
#
# File ~/GITHUB/Exploring_Agents/.venv/lib/python3.12/site-packages/ollama/_client.py:179, in Client._request.<locals>.inner()
#     177 except httpx.HTTPStatusError as e:
#     178   e.response.read()
# --> 179   raise ResponseError(e.response.text, e.response.status_code) from None
#     181 for line in r.iter_lines():
#     182   part = json.loads(line)
#
# ResponseError: model 'llama3.1:8b-instruct-q4_K_M' not found (status code: 404)
